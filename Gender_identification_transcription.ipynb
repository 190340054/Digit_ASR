# %%
import os

hash = ['zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']
file_path = '/home/vishnu/Documents/Digit_data_train/gender_train_trancript.txt'

for dirname, _, filenames in os.walk('/home/vishnu/Documents/Digit_data_train/train'):
    filenames = sorted(filenames)
    for filename in filenames:
        extract_path  = filename.split('.')[-2]
        extract_word = extract_path.split('_')[-3]
        extract_gender = extract_word.split('0')[-2]
  
        if len(extract_gender) == 2:
            extract_gender = extract_gender.split('1')[-0]    
        else:
            extract_gender = extract_gender
            
        with open(file_path, 'a') as f:
            f.write(extract_path + '\t' + extract_gender + '\n')
            print(extract_path, extract_gender)
# Out:
# V52_M05_U1_D0 M
# V52_M05_U1_D1 M
# V52_M05_U1_D2 M
# V52_M05_U1_D3 M
# V52_M05_U1_D4 M
# V52_M05_U1_D5 M
# V52_M05_U1_D6 M
# V52_M05_U1_D7 M
# V52_M05_U1_D8 M
# V52_M05_U1_D9 M
# V52_M05_U2_D0 M
# V52_M05_U2_D1 M
# V52_M05_U2_D2 M
# V52_M05_U2_D3 M
# V52_M05_U2_D4 M
# V52_M05_U2_D5 M
# V52_M05_U2_D6 M
# V52_M05_U2_D7 M
# V52_M05_U2_D8 M
# V52_M05_U2_D9 M
# V52_M05_U3_D0 M
# V52_M05_U3_D1 M
# V52_M05_U3_D2 M
# V52_M05_U3_D3 M
# V52_M05_U3_D4 M
# V52_M05_U3_D5 M
# V52_M05_U3_D6 M
# V52_M05_U3_D7 M
# V52_M05_U3_D8 M
# V52_M05_U3_D9 M
# V37_M02_U1_D0 M
# V37_M02_U1_D1 M
# V37_M02_U1_D2 M
# V37_M02_U1_D3 M
# V37_M02_U1_D4 M
# V37_M02_U1_D5 M
# V37_M02_U1_D6 M
# V37_M02_U1_D7 M
# V37_M02_U1_D8 M
# V37_M02_U1_D9 M
# V37_M02_U2_D0 M
# V37_M02_U2_D1 M
# V37_M02_U2_D2 M
# V37_M02_U2_D3 M
# V37_M02_U2_D4 M
# V37_M02_U2_D5 M
# V37_M02_U2_D6 M
# V37_M02_U2_D7 M
# V37_M02_U2_D8 M
# V37_M02_U2_D9 M
# V37_M02_U3_D0 M
# V37_M02_U3_D1 M
# V37_M02_U3_D2 M
# V37_M02_U3_D3 M
# V37_M02_U3_D4 M
# ...
