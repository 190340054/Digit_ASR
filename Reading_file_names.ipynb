# %%
# !pip install pyunpack
# !pip install patool

# %%
import os
from pyunpack import Archive
import shutil

if not os.path.exists('/home/vishnu/Documents/Digit_data_train/'):
    os.makedirs('/home/vishnu/Documents/Digit_data_train/train')
Archive('/home/vishnu/Documents/Digit_data_train/train.zip').extractall('/home/vishnu/Documents/Digit_data_train/')
for dirname, _, filenames in os.walk('/home/vishnu/Documents/Digit_data_train/'):
    filenames = sorted(filenames)
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /home/vishnu/Documents/Digit_data_train/train.zip
# /home/vishnu/Documents/Digit_data_train/train/V52_M05_U_D/V52_M05_U1_D0.wav
# /home/vishnu/Documents/Digit_data_train/train/V52_M05_U_D/V52_M05_U1_D1.wav
# /home/vishnu/Documents/Digit_data_train/train/V52_M05_U_D/V52_M05_U1_D2.wav
# /home/vishnu/Documents/Digit_data_train/train/V52_M05_U_D/V52_M05_U1_D3.wav
# /home/vishnu/Documents/Digit_data_train/train/V52_M05_U_D/V52_M05_U1_D4.wav
# /home/vishnu/Documents/Digit_data_train/train/V52_M05_U_D/V52_M05_U1_D5.wav
# /home/vishnu/Documents/Digit_data_train/train/V52_M05_U_D/V52_M05_U1_D6.wav
# /home/vishnu/Documents/Digit_data_train/train/V52_M05_U_D/V52_M05_U1_D7.wav
# /home/vishnu/Documents/Digit_data_train/train/V52_M05_U_D/V52_M05_U1_D8.wav
# /home/vishnu/Documents/Digit_data_train/train/V52_M05_U_D/V52_M05_U1_D9.wav
# /home/vishnu/Documents/Digit_data_train/train/V52_M05_U_D/V52_M05_U2_D0.wav
# /home/vishnu/Documents/Digit_data_train/train/V52_M05_U_D/V52_M05_U2_D1.wav
# ...
